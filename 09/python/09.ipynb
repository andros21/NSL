# %% [markdown]
# # NSL Notebook 09
#
# ## Exercise 09.1.1

# %%
######                        #######
##  IMPORT DEFAULT PKGS and VARS   ##
######                        #######

from default import *

# %%
fig, ax = plt.subplots(1,2, figsize=(14,6) )

dfb = pd.read_csv('bL1OC.out', header=None, names=['L1'])

dfbh = pd.read_csv('bHAL1OC.out', header=None, names=['haL1'])

dfb['L1'].plot.line(ls='-', c='r', ax=ax[0]);
dfbh['haL1'].plot.line(ls='-', c='b', ax=ax[1]);

ax[0].set_xlabel('\# iter')
ax[0].set_ylabel('$L1$')

ax[1].set_xlabel('\# iter')
ax[1].set_ylabel('$\langle L1 \\rangle$')
ax[1].yaxis.tick_right()

# %%
from matplotlib.animation import FuncAnimation
from time import sleep

fig, (axb, axa) = plt.subplots(1,2, figsize=(10,5));

dfb = pd.read_csv('circle.tsv', header=None, sep='\t', names=['x','y']);
dfa = pd.read_csv('OC.csv', header=None, sep=',', names=['x','y']);

xb = [dfb['x'][0]]
yb = [dfb['y'][0]]

xa = [dfa['x'][0]]
ya = [dfa['y'][0]]

def func(npt, *fargs):
    xb.append(npt[0][0])
    yb.append(npt[0][1])
    xa.append(npt[1][0])
    ya.append(npt[1][1])
    axb.plot(xb,yb, '-r');
    axa.plot(xa,ya, '-b');
    xb.pop(0)
    yb.pop(0)
    xa.pop(0)
    ya.pop(0)
    
def init_func():
    axb.scatter(dfb['x'], dfb['y'], marker='.', color='k');
    axa.scatter(dfa['x'], dfa['y'], marker='.', color='k');
    sleep(1);
    
    
frames = []
for ptb, pta in zip(np.asarray(dfb), np.asarray(dfa)):
    frames.append((ptb, pta))
    
anim = FuncAnimation(fig, func, frames, init_func, interval=300);
anim.save('OC.mp4', writer="ffmpeg");

# %% [markdown]
# ## Exercise 09.1.2

# %%
fig, ax = plt.subplots(1,2, figsize=(14,6) )

dfb = pd.read_csv('bL1IS.out', header=None, names=['L1'])

dfbh = pd.read_csv('bHAL1IS.out', header=None, names=['haL1'])

dfb['L1'].plot.line(ls='-', c='r', ax=ax[0]);
dfbh['haL1'].plot.line(ls='-', c='b', ax=ax[1]);

ax[0].set_xlabel('\# iter')
ax[0].set_ylabel('$L1$')

ax[1].set_xlabel('\# iter')
ax[1].set_ylabel('$\langle L1 \\rangle$')
ax[1].yaxis.tick_right()

# %%
from matplotlib.animation import FuncAnimation
from time import sleep

fig, (axb, axa) = plt.subplots(1,2, figsize=(10,5));

dfb = pd.read_csv('square.tsv', header=None, sep='\t', names=['x','y']);
dfa = pd.read_csv('IS.csv', header=None, sep=',', names=['x','y']);

xb = [dfb['x'][0]]
yb = [dfb['y'][0]]

xa = [dfa['x'][0]]
ya = [dfa['y'][0]]

def func(npt, *fargs):
    xb.append(npt[0][0])
    yb.append(npt[0][1])
    xa.append(npt[1][0])
    ya.append(npt[1][1])
    axb.plot(xb,yb, '-r');
    axa.plot(xa,ya, '-b');
    xb.pop(0)
    yb.pop(0)
    xa.pop(0)
    ya.pop(0)
    
def init_func():
    axb.scatter(dfb['x'], dfb['y'], marker='.', color='k');
    axa.scatter(dfa['x'], dfa['y'], marker='.', color='k');
    sleep(1);
    
    
frames = []
for ptb, pta in zip(np.asarray(dfb), np.asarray(dfa)):
    frames.append((ptb, pta))
    
anim = FuncAnimation(fig, func, frames, init_func, interval=300);
anim.save('IS.mp4', writer="ffmpeg");
