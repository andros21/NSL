# %% [markdown]
# # NSL Notebook 09
#
# ## Exercise 09.1

# %%
######                        #######
##  IMPORT DEFAULT PKGS and VARS   ##
######                        #######

from default import *

# %%
fig, ax = plt.subplots(figsize=(5,5))

df = pd.read_csv('square.tsv', header=None, sep='\t', names=['x','y']);

ax.plot(df['x'], df['y'], '--r', marker='.');
